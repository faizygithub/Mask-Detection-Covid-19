# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.2'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
RESEARCH_DIR='/content/gdrive/My Drive/MaskDetection/models/research'

# %%
os.chdir(RESEARCH_DIR)

# %%
os.getcwd()
# Out:
# '/content/gdrive/My Drive/MaskDetection/models/research'

# %%
# !python train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/faster_rcnn_inception_v2_coco.config
# Out:
# Streaming output truncated to the last 5000 lines.
# I0520 09:00:04.922773 140443349747584 learning.py:507] global step 47507: loss = 0.0492 (0.136 sec/step)
# INFO:tensorflow:global step 47508: loss = 0.0883 (0.125 sec/step)
# I0520 09:00:05.049417 140443349747584 learning.py:507] global step 47508: loss = 0.0883 (0.125 sec/step)
# INFO:tensorflow:global step 47509: loss = 0.0773 (0.133 sec/step)
# I0520 09:00:05.184375 140443349747584 learning.py:507] global step 47509: loss = 0.0773 (0.133 sec/step)
# INFO:tensorflow:global step 47510: loss = 0.0292 (0.137 sec/step)
# I0520 09:00:05.322731 140443349747584 learning.py:507] global step 47510: loss = 0.0292 (0.137 sec/step)
# INFO:tensorflow:global step 47511: loss = 0.0565 (0.128 sec/step)
# I0520 09:00:05.452511 140443349747584 learning.py:507] global step 47511: loss = 0.0565 (0.128 sec/step)
# INFO:tensorflow:global step 47512: loss = 0.1934 (0.158 sec/step)
# ...

# %%
# !python export_inference_graph.py --input_type image_tensor --pipeline_config_path training/faster_rcnn_inception_v2_coco.config --trained_checkpoint_prefix training/model.ckpt-50000 --output_directory inference_graph
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/MaskDetection/models/research/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/MaskDetection/models/research/nets/mobilenet/mobilenet.py:389: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From export_inference_graph.py:150: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# ...
